# %%
import requests
import pandas as pd
from requests.exceptions import RequestException
import time
from datetime import datetime, timedelta

# LTA API URL for Traffic Speed Bands
url = "http://datamall2.mytransport.sg/ltaodataservice/v3/TrafficSpeedBands"

api_key_lta = 'pls-refer-to-the-submitted-notebook'

# Your API key (replace 'your_api_key' with your actual LTA API key)
headers = {
    'AccountKey': api_key_lta,  # Replace with your actual API key
    'accept': 'application/json'
}

# Function to fetch traffic speed bands data from LTA API
def fetch_traffic_speed_bands():
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Check for HTTP errors
        return response.json().get('value', [])
    except RequestException as e:
        print(f"Error fetching traffic speed bands data: {e}")
        return []

# Function to process and export data to CSV
def export_to_csv(data, file_path):
    if not data:
        print("No data to save.")
        return
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Include a timestamp column in the DataFrame
    df['Timestamp'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    # Save to CSV with timestamp in filename to avoid overwriting
    file_name = f'traffic_speed_bands_{datetime.now().strftime("%Y%m%d_%H%M%S")}.csv'
    df.to_csv(file_path + file_name, index=False)
    print(f"CSV file saved to: {file_path + file_name}")

# Function to run the task every hour
def run_hourly_task():
    traffic_data = fetch_traffic_speed_bands()
    csv_file_path = r'C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\'  
    export_to_csv(traffic_data, csv_file_path)

# Function to calculate the initial wait time until the first API call
def calculate_initial_wait(start_time):
    now = datetime.now()
    target_time = datetime.combine(now.date(), start_time)
    
    if now > target_time:
        # If the current time is past the start_time, calculate for the next day
        target_time += timedelta(days=1)
    
    wait_time = (target_time - now).total_seconds()
    return wait_time

# Main loop to run the task every hour starting from the given start_time
def hourly_loop(start_time):
    # Wait until the specified start_time
    wait_time = calculate_initial_wait(start_time)
    print(f"Waiting {wait_time / 60:.2f} minutes until the first run at {start_time}.")
    time.sleep(wait_time)
    
    # Start the hourly task
    while True:
        print(f"Fetching data at {datetime.now()}")
        run_hourly_task()
        time.sleep(3600)  # Sleep for 1 hour between API calls

# Example usage with custom start time
if __name__ == "__main__":
    # Specify the start time (e.g., 14:00 or 2 PM)
    start_time = datetime.strptime("03:00", "%H:%M").time()  # Change this to your desired start time
    hourly_loop(start_time)
# Out:
# Waiting 15.61 minutes until the first run at 03:00:00.
# Fetching data at 2024-10-02 03:00:00.000879
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_030000.csv
# Fetching data at 2024-10-02 04:00:00.061197
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_040000.csv
# Fetching data at 2024-10-02 05:00:00.393355
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_050000.csv
# Fetching data at 2024-10-02 06:00:00.739261
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_060000.csv
# Fetching data at 2024-10-02 07:00:00.895043
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_070001.csv
# Fetching data at 2024-10-02 08:00:01.069517
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_080001.csv
# Fetching data at 2024-10-02 09:00:01.199800
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_090001.csv
# Fetching data at 2024-10-02 10:00:01.267396
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_100001.csv
# Fetching data at 2024-10-02 11:00:01.590814
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_110001.csv
# Fetching data at 2024-10-02 12:00:01.681060
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_120002.csv
# Fetching data at 2024-10-02 13:00:02.788396
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_130002.csv
# Fetching data at 2024-10-02 14:00:03.125892
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_140003.csv
# Fetching data at 2024-10-02 15:00:03.387445
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_150003.csv
# Fetching data at 2024-10-02 16:00:03.540945
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_160003.csv
# Fetching data at 2024-10-02 17:00:03.649584
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_170003.csv
# Fetching data at 2024-10-02 18:00:03.751631
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_180003.csv
# Fetching data at 2024-10-02 19:00:03.851307
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_190003.csv
# Fetching data at 2024-10-02 20:00:03.947304
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_200004.csv
# Fetching data at 2024-10-02 21:00:04.121616
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_210004.csv
# Fetching data at 2024-10-02 22:00:04.285160
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_220004.csv
# Fetching data at 2024-10-02 23:00:04.557662
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241002_230004.csv
# Fetching data at 2024-10-03 00:00:04.815832
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_000004.csv
# Fetching data at 2024-10-03 01:00:05.025323
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_010005.csv
# Fetching data at 2024-10-03 02:00:05.145828
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_020005.csv
# Fetching data at 2024-10-03 03:00:05.247844
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_030005.csv
# Fetching data at 2024-10-03 04:00:05.493792
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_040005.csv
# Fetching data at 2024-10-03 05:00:05.602777
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_050005.csv
# Fetching data at 2024-10-03 06:00:05.713405
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_060005.csv
# Fetching data at 2024-10-03 07:00:05.827873
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_070005.csv
# Fetching data at 2024-10-03 08:00:06.069823
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_080006.csv
# Fetching data at 2024-10-03 09:00:06.328423
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_090006.csv
# Fetching data at 2024-10-03 10:00:06.598081
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_100006.csv
# Fetching data at 2024-10-03 11:00:06.751630
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_110006.csv
# Fetching data at 2024-10-03 12:00:06.951974
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_120008.csv
# Fetching data at 2024-10-03 13:00:08.114398
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_130008.csv
# Fetching data at 2024-10-03 14:00:08.271703
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_140008.csv
# Fetching data at 2024-10-03 15:00:08.446049
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_150008.csv
# Fetching data at 2024-10-03 16:00:08.588150
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_160008.csv
# Fetching data at 2024-10-03 17:00:08.751262
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_170008.csv
# Fetching data at 2024-10-03 18:00:08.974740
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_180009.csv
# Fetching data at 2024-10-03 19:00:09.146375
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_190009.csv
# Fetching data at 2024-10-03 20:00:09.266571
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_200009.csv
# Fetching data at 2024-10-03 21:00:09.372356
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_210009.csv
# Fetching data at 2024-10-03 22:00:09.500309
# CSV file saved to: C:\Users\jayde\OneDrive - National University of Singapore\Desktop\NUS Master\2024-2025 Sem 1\IS5126\Group Assignment\Speed\\traffic_speed_bands_20241003_220009.csv
